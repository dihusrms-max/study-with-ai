# %% [markdown]
# ### 데이터 병합
# - 모든 필요한 데이터가 하나의 파일에 있는 것은 아니다
# - 도시 공원이 충분한지
# - 지역마다 격차가 없는지
# - 공원 데이터로만 보면 면적이 넓은 도시가 조을 수 있음
# 인구가 많다면 아닐 수 있음
#
# 시민 1명당 공원면적을 봐야 -> 진짜 비교가 가능하다

# %% [markdown]
# 1. 데이터 병합 - concat

# %%
import pandas as pd

daejeon_park = pd.DataFrame({
    "지역": ["대전", "대전", "대전"],
    "공원명": ["한밭수목원", "샘머리공원", "올림픽체육공원"],
    "공원구분": ["도시자연공원", "근린공원", "체육공원"],
    "공원면적": [387000, 12500, 45000],
})

sejong_park = pd.DataFrame({
    "지역": ["세종", "세종", "세종"],
    "공원명": ["세종호수공원", "방축천공원", "밀마루전망공원"],
    "공원구분": ["도시자연공원", "근린공원", "근린공원"],
    "공원면적": [705000, 32000, 8900],
})

total_dt = pd.concat(dat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 17
#      13     "공원구분": ["도시자연공원", "근린공원", "근린공원"],
#      14     "공원면적": [705000, 32000, 8900],
#      15 })
#      16
# ---> 17 total_dt = pd.concat(dat)
#
# NameError: name 'dat' is not defined

# %%
total_df = pd.concat([daejeon_park, sejong_park], ignore_index=False)
total_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 total_df = pd.concat([daejeon_park, sejong_park], ignore_index=False)
#       2 total_df
#
# NameError: name 'pd' is not defined

# %% [markdown]
# 가로합칰기 - merge

# %%
total_df = pd.DataFrame([daejeon_park, sejong_park], ignore_index=False)
total_df

# %%
merged_df= pd.merge(total_df, data1, on="지역", how="right")
merged_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 merged_df= pd.merge(total_df, data1, on="지역")
#       2 merged_df
#
# NameError: name 'pd' is not defined

# %%
total_Df.groupby()wldurrhddnsjausswrp[sum reest rese_index()]
