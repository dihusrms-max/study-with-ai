# %% [markdown]
# ### 1. API와 HTTP 정리
# - API는 프로그램과 데이터를 주고 받는 약속
# ex) 직접주문 지양 - 간접주문을 통해 공통된 api 사용 - 요청 데이터 받기
# --
# - HTTP : 프로그램이 서버에 요청을 보내는 규칙
# - GET : 데이터 조회
# - POST : 데이터 전송

# %% [markdown]
# ### 2. requests 라이브러리 GET 요청
# - 설치 : uv add requests
# - 주소 : GET요청을 보내면 JSON 으로 응답

# %%
import requests
url = "https://jsonplaceholder.typicode.com/todos/1"
res = requests.get(url)
status = res.status_code
data = res.json()
print(data)
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %%
# 테스트 한번더 - params

url = "https://jsonplaceholder.typicode.com/posts/1/comments"
res = requests.get(url, params={"postId": 1})
status = res.status_code
data = res.json()
print(data)
# Out:
# [{'postId': 1, 'id': 1, 'name': 'id labore ex et quam laborum', 'email': 'Eliseo@gardner.biz', 'body': 'laudantium enim quasi est quidem magnam voluptate ipsam eos\ntempora quo necessitatibus\ndolor quam autem quasi\nreiciendis et nam sapiente accusantium'}, {'postId': 1, 'id': 2, 'name': 'quo vero reiciendis velit similique earum', 'email': 'Jayne_Kuhic@sydney.com', 'body': 'est natus enim nihil est dolore omnis voluptatem numquam\net omnis occaecati quod ullam at\nvoluptatem error expedita pariatur\nnihil sint nostrum voluptatem reiciendis et'}, {'postId': 1, 'id': 3, 'name': 'odio adipisci rerum aut animi', 'email': 'Nikita@garfield.biz', 'body': 'quia molestiae reprehenderit quasi aspernatur\naut expedita occaecati aliquam eveniet laudantium\nomnis quibusdam delectus saepe quia accusamus maiores nam est\ncum et ducimus et vero voluptates excepturi deleniti ratione'}, {'postId': 1, 'id': 4, 'name': 'alias odio sit', 'email': 'Lew@alysha.tv', 'body': 'non et atque\noccaecati deseru
# ...

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 5

# %%
data[0]
# Out:
# {'postId': 1,
#  'id': 1,
#  'name': 'id labore ex et quam laborum',
#  'email': 'Eliseo@gardner.biz',
#  'body': 'laudantium enim quasi est quidem magnam voluptate ipsam eos\ntempora quo necessitatibus\ndolor quam autem quasi\nreiciendis et nam sapiente accusantium'}

# %%
emails = []

for i in data:
    emails.append(i["email"])
print(emails)
# Out:
# ['Eliseo@gardner.biz', 'Jayne_Kuhic@sydney.com', 'Nikita@garfield.biz', 'Lew@alysha.tv', 'Hayden@althea.biz']

# %%
# 연습 - 1.  body 내용만 담긴 리스트 만들기
# 연습 - 2.  https: ~ 주소에서 userId가 1인 사람 타이틀만 저장

# %%
url = "https://jsonplaceholder.typicode.com/posts/1/comments"
res = requests.get(url, params={"userId": 1})
status = res.status_code
data = res.json()
bodies = [comment["body"] for comment in data] # list 컴프리헨션 사용 

print(bodies)
# Out:
# ['laudantium enim quasi est quidem magnam voluptate ipsam eos\ntempora quo necessitatibus\ndolor quam autem quasi\nreiciendis et nam sapiente accusantium', 'est natus enim nihil est dolore omnis voluptatem numquam\net omnis occaecati quod ullam at\nvoluptatem error expedita pariatur\nnihil sint nostrum voluptatem reiciendis et', 'quia molestiae reprehenderit quasi aspernatur\naut expedita occaecati aliquam eveniet laudantium\nomnis quibusdam delectus saepe quia accusamus maiores nam est\ncum et ducimus et vero voluptates excepturi deleniti ratione', 'non et atque\noccaecati deserunt quas accusantium unde odit nobis qui voluptatem\nquia voluptas consequuntur itaque dolor\net qui rerum deleniti ut occaecati', 'harum non quasi et ratione\ntempore iure ex voluptates in ratione\nharum architecto fugit inventore cupiditate\nvoluptates magni quo et']

# %%
url = "https://jsonplaceholder.typicode.com/posts/1/comments"
res = requests.get(url, params={"userId": 1})
status = res.status_code
data = res.json()
print(data)
# Out:
# [{'postId': 1, 'id': 1, 'name': 'id labore ex et quam laborum', 'email': 'Eliseo@gardner.biz', 'body': 'laudantium enim quasi est quidem magnam voluptate ipsam eos\ntempora quo necessitatibus\ndolor quam autem quasi\nreiciendis et nam sapiente accusantium'}, {'postId': 1, 'id': 2, 'name': 'quo vero reiciendis velit similique earum', 'email': 'Jayne_Kuhic@sydney.com', 'body': 'est natus enim nihil est dolore omnis voluptatem numquam\net omnis occaecati quod ullam at\nvoluptatem error expedita pariatur\nnihil sint nostrum voluptatem reiciendis et'}, {'postId': 1, 'id': 3, 'name': 'odio adipisci rerum aut animi', 'email': 'Nikita@garfield.biz', 'body': 'quia molestiae reprehenderit quasi aspernatur\naut expedita occaecati aliquam eveniet laudantium\nomnis quibusdam delectus saepe quia accusamus maiores nam est\ncum et ducimus et vero voluptates excepturi deleniti ratione'}, {'postId': 1, 'id': 4, 'name': 'alias odio sit', 'email': 'Lew@alysha.tv', 'body': 'non et atque\noccaecati deseru
# ...

# %%
# 1. for문
bodies = []

for comment in data:
    bodies.append(comment["body"])

# 2. map 함수
bodies = list(map(lambda comment: comment["body"],data))

# 3.dict None 값 방지를 위한 .get()

bodies = [comment.get("body") for comment in data]/
"""
리스트 컴프리헨션: 짧고 읽기 쉬움 → 추천
for문: 중간 처리 조건이 많을 때 유리
map: 가능하지만 Python에서는 보통 덜 직관적
"""

# %%
### 공공데이터 API 사용

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
service_key=os.getenv("SERVICE_KEY")

# %%
import requests
# https://api.kcisa.kr/openapi/service/rest/convergence2019/getConver10?serviceKey=c6fec154-9596-439d-bcb2-6972c0ccd3ad&numOfRows=10&pageNo=1
url = "https://api.kcisa.kr/openapi/service/rest/convergence2019/getConver10"


headers = {

"Accept" : "application/json"

}

params={
    "serviceKey" : service_key,
    "numOfRows": 10,
    "pageNo" : 1,
    # "Keyword" : "축제",
    "where" : "서울"
}
response = requests.get(url,
                        params=params,
                        headers=headers
                        )
print(response.status_code)
# Out:
# 200

# %%
print(response.text)
# Out:
# {"response":{"header":{"resultCode":"0000","resultMsg":"OK"},"body":{"items":{"item":[{"rnum":"1","publisher":null,"creator":"공공데이터포털","collectionDb":"시티투어데이터 DB","title":"어라운드 강남 코스","subjectKeyword":null,"referenceIdentifier":null,"alternativeTitle":null,"extent":"순환형","medium":null,"temporal":null,"reference":"시티투어문의처: 02-777-6090(서울시티투어버스 본점) | 관리기관문의처: 02-3423-5546","rights":"서울특별시 강남구청","source":"http://www.seoulcitybus.com","charge":"성인15000/소인12000 | 강남북 통합권성인 24000원~35000원","venue":"탑승장소: 강남역 및 어라운드 강남코스 모든 정류소","time":"연중 화요일~일요일 운행(매주 월요일 휴행)","description":"코스정보: 강남역/노보텔 르메르디앙서울/삼정호텔/선정릉 라마다호텔/봉은사 롯데면세점/코엑스 에스엠타운/롯데호텔 / 롯데월드/롯데월드타워/올림픽공원/잠실종합운동장/삼성역/K-POP엔터테인먼트사/한류스타거리/압구정로데오거리/강남관광정보센터 현대백화점/가로수길 남단/세빛섬/고속터미널상가 신세계백화점/서래마을/교대역/삼성딜라이트/ 강남역","subDescription":"경유지정보: 강남역 빛의 거리+강남스퀘어+국기원+선정릉+봉은사+코엑스+롯데월드+롯데월드타워+올림픽공원+청담동 명품거리+압구정로데오거리+가로수길 | 부가정보: 강남역 11번 출구에서 200미터 직진 시 강남시티투어 안내소 위치 | 운행정보: 매주 월요일 휴행","spatial":"서울특별시 강남구","url":"-"},{"rnum":"2","publisher":null,"creator":
# ...

# %%
data = response.json()
data['response']['body']['items']['item']
# Out:
# [{'rnum': '1',
#   'publisher': None,
#   'creator': '공공데이터포털',
#   'collectionDb': '시티투어데이터 DB',
#   'title': '어라운드 강남 코스',
#   'subjectKeyword': None,
#   'referenceIdentifier': None,
#   'alternativeTitle': None,
#   'extent': '순환형',
#   'medium': None,
#   'temporal': None,
#   'reference': '시티투어문의처: 02-777-6090(서울시티투어버스 본점) | 관리기관문의처: 02-3423-5546',
#   'rights': '서울특별시 강남구청',
#   'source': 'http://www.seoulcitybus.com',
#   'charge': '성인15000/소인12000 | 강남북 통합권성인 24000원~35000원',
#   'venue': '탑승장소: 강남역 및 어라운드 강남코스 모든 정류소',
#   'time': '연중 화요일~일요일 운행(매주 월요일 휴행)',
#   'description': '코스정보: 강남역/노보텔 르메르디앙서울/삼정호텔/선정릉 라마다호텔/봉은사 롯데면세점/코엑스 에스엠타운/롯데호텔 / 롯데월드/롯데월드타워/올림픽공원/잠실종합운동장/삼성역/K-POP엔터테인먼트사/한류스타거리/압구정로데오거리/강남관광정보센터 현대백화점/가로수길 남단/세빛섬/고속터미널상가 신세계백화점/서래마을/교대역/삼성딜라이트/ 강남역',
#   'subDescription': '경유지정보: 강남역 빛의 거리+강남스퀘어+국기원+선정릉+봉은사+코엑스+롯데월드+롯데월드타워+올림픽공원+청담동 명품거리+압구정로데오거리+가로수길 | 부가정보: 강남역 11번 출구에서 200미터 직진 시 강남시티투어 안내소 위치 | 운행정보: 매주 월요일 휴행',
#   'spatial': '서울특별시 강남구',
#   'url': '-'},
# ...

# %%
len(data['response']['body']['items']['item'])
# Out:
# 21

# %%
import requests
# https://api.kcisa.kr/openapi/service/rest/convergence2019/getConver10?serviceKey=c6fec154-9596-439d-bcb2-6972c0ccd3ad&numOfRows=10&pageNo=1
url = "https://api.kcisa.kr/openapi/service/rest/convergence2019/getConver10"


headers = {

"Accept" : "application/json"

}

total_data=[]


# pageNo
for pageNo in range(1,6):
    params={
        "serviceKey" : service_key,
        "numOfRows": 10,
        "pageNo" : 1,
        # "Keyword" : "축제",
        "where" : "서울"
    }
    response = requests.get(url,
                            params=params,
                            headers=headers
                            )
    print(response.status_code)
    data=response.json()
    total_data += (data['response']['body']['items']['item']) #리스트는 데이터를 합치는 게 가능
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
# 키워드 변경해서 테스트
# 위치 도 변경
# 파라미터 조건을 수정해서 테스트

# %%
import requests
# https://api.kcisa.kr/openapi/service/rest/convergence2019/getConver10?serviceKey=c6fec154-9596-439d-bcb2-6972c0ccd3ad&numOfRows=10&pageNo=1
url = "https://api.kcisa.kr/openapi/service/rest/convergence2019/getConver10"


headers = {

"Accept" : "application/json"

}

total_data=[]


# pageNo
for pageNo in range(1,6):
    params={
        "serviceKey" : service_key,
        "numOfRows": 10,
        "pageNo" : 1,
        # "Keyword" : "축제",
        "where" : "강원도"
    }
    response = requests.get(url,
                            params=params,
                            headers=headers
                            )
    print(response.status_code)
    data=response.json()
    total_data += (data['response']['body']['items']['item']) #리스트는 데이터를 합치는 게 가능
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
data.keys() # 키 목록이 딕셔너리 또는 리스트인지 자료구조 파악
data['response'].keys() #딕셔너리 안에 무엇이 있는 지 계속해서 확인해야함 
data['response']['body']['items']['item']

items = data['response']['body']['items']['item']
items[0].keys()
items[0]["rnum"]
# Out:
# '1'

# %%
## 결과를 판다스로 확인
import pandas as pd
[{},{},{}]

df = pd.DataFrame(total_data)

# %%
df.to_csv("public_data.csv", encoding="utf-8-sig")
