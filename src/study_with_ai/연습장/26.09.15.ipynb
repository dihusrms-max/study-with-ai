# %% [markdown]
# 모델 조정 : 프롬프트 엔지니어링의 모델 결과를 정교하게 다듬는 과정을 말한다
# - 가중치 조정 X
# - 모델의 응답만 조정 O
# - 사람-AI 소통으로 쉽지만 효과적인 프롬프트와는 다르다 - 엄격성이 달라 의미 없다
# - 개체명 인식 (NER) - 작업에 활용할 수 있는 간단한 프롬프트
#     - 과제설명
#     - 예시
#     - 과제
# - 모델이 얼마나 프롬프트에 대해 변화성에 대한 평가 요소 필요 - 간겅성 측정
# - 모델이 강건- 모델의 성능이 높을 수록 높은 값 출력 - 5와five를 구분하는 시간이 줄어들음
