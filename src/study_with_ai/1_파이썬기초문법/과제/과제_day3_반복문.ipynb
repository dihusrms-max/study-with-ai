# %% [markdown]
# # 과제 · 반복문
#
# 오늘 배운 **반복문**으로 풀어봅니다. (지금까지 배운 변수·연산·문자열·자료구조도 함께 씁니다.)
# **함수(`def`)는 아직 쓰지 않습니다.**
#
# 난이도: ⭐ 기초 → ⭐⭐ 기본 → ⭐⭐⭐ 응용 → ⭐⭐⭐⭐ 도전.
# `# TODO`를 채워 실행하고 **예상 출력**과 비교하세요. 기초부터 하나씩!

# %% [markdown]
# ## 문제 1. 숫자 세기 · ⭐ 기초
#
# `for`와 `range`로 **1부터 5까지** 한 줄에 하나씩 출력하세요.

# %%
# TODO: for i in range(1, 6): 로 출력

for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## 문제 2. 1부터 10까지 합 · ⭐ 기초
#
# `for`로 **1~10의 합**을 구해 출력하세요.

# %%
합 = 0
# TODO: for 로 1~10 을 더하기

for i in range(1,11):
    합+=i

print("합:", 합)
# 예상: 합: 55
# Out:
# 합: 55

# %% [markdown]
# ## 문제 3. 과일 부르기 · ⭐ 기초
#
# 리스트를 `for`로 돌며 과일을 하나씩 출력하세요.

# %%
과일 = ["사과", "바나나", "포도"]
# TODO: for 로 하나씩 출력

for i in 과일 : 
    print(i)
# Out:
# 사과
# 바나나
# 포도

# %% [markdown]
# ## 문제 4. 카운트다운 · ⭐ 기초
#
# `while`로 5, 4, 3, 2, 1 을 출력하세요.

# %%
n = 5
# TODO: while n >= 1: 출력하고 n 을 1 줄이기

while n >=1 :
    print(n)
    n-=1
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# ## 문제 5. 구구단 3단 · ⭐⭐ 기본
#
# `for`로 3단(`3 x 1 = 3` ... `3 x 9 = 27`)을 출력하세요.

# %%
# TODO: for i in range(1, 10): print(f"3 x {i} = {3*i}")


for i in range(1,9): 
    print(f"3 X {i} = {3*i}")
# Out:
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24

# %% [markdown]
# ## 문제 6. 점수 합계와 평균 · ⭐⭐ 기본
#
# 점수 리스트를 `for`로 더해 **합계와 평균**을 출력하세요.

# %%
점수 = [88, 92, 76, 100, 64]
합 = 0
# TODO: for 로 합을 구하고, 평균 = 합 / 개수

for i in 점수 : 
    if i>0:
        합+=i


print("합계:", 합, "/ 평균:", 합 / len(점수))
# 예상: 합계 420 / 평균 84.0
# Out:
# 합계: 420 / 평균: 84.0

# %% [markdown]
# ## 문제 7. 성인 세기 · ⭐⭐ 기본
#
# 나이 리스트에서 **19세 이상이 몇 명**인지 세어 출력하세요. (for + if)

# %%
나이 = [15, 22, 34, 18, 40, 12]
성인 = 0
# TODO: for 로 돌며 19 이상이면 성인 += 1

for i in 나이 :
    if i > 19:
        성인 +=1

print("성인:", 성인, "명")
# 예상: 성인 3 명
# Out:
# 성인: 3 명

# %% [markdown]
# ## 문제 8. 짝수만 모으기 · ⭐⭐ 기본
#
# 숫자 리스트에서 **짝수만** 골라 새 리스트에 모아 출력하세요. (for + if + append)

# %%
숫자 = [7, 4, 9, 2, 8, 5, 10]
짝수 = []
# TODO: for 로 돌며 짝수면 append

for i in 숫자:
    if i % 2 == 0:
        짝수.append(i)


print("짝수:", 짝수)
# 예상: 짝수 [4, 2, 8, 10]
# Out:
# 짝수: [4, 2, 8, 10]

# %% [markdown]
# ## 문제 9. 별 피라미드 · ⭐⭐⭐ 응용
#
# `for`로 별(`*`)을 1개, 2개, 3개, 4개, 5개 늘려가며 출력하세요. (힌트: `"*" * i`)

# %%
# TODO: for i in range(1, 6): print("*" * i)

for i in range(1,6):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# ## 문제 10. 합격자 명단 · ⭐⭐⭐ 응용
#
# 점수 딕셔너리를 순회하며 **80점 이상 합격자 이름**만 출력하세요. (for + items + if)

# %%
점수 = {"민수": 90, "지현": 55, "수호": 100, "예린": 88}
# TODO: for 이름, 점 in 점수.items(): 80 이상이면 이름 출력

for i, ii in 점수.items():
    if ii >=80 :
        print(i)
# Out:
# 민수
# 수호
# 예린

# %% [markdown]
# ## 도전 1. 369 게임 · ⭐⭐⭐⭐ 도전
#
# 1부터 20까지 세되, **3의 배수(3,6,9...)에서는 `"짝"`**, 아니면 숫자를 출력하세요.

# %%
# TODO: for n in range(1, 21): 3의 배수면 "짝", 아니면 n

for n in range(1,21):
    if n % 3 == 0:
        print(" 짝수 입니다")
    else :
        print(n)
# Out:
# 1
# 2
#  짝수 입니다
# 4
# 5
#  짝수 입니다
# 7
# 8
#  짝수 입니다
# 10
# 11
#  짝수 입니다
# 13
# 14
#  짝수 입니다
# 16
# 17
#  짝수 입니다
# 19
# 20

# %% [markdown]
# ## 도전 2. 구구단 전체 · ⭐⭐⭐⭐ 도전
#
# 2단부터 9단까지 모두 출력하세요. (반복문 안에 반복문 - 2중 for)

# %%
# TODO: for 단 in range(2, 10): 안에서 for i in range(1, 10):
for i in range(2,10) :
    print("-----------")
    for ii in range(1,10):
        print(f"{i}X{ii}={i*ii}")
# Out:
# -----------
# 2X1=2
# 2X2=4
# 2X3=6
# 2X4=8
# 2X5=10
# 2X6=12
# 2X7=14
# 2X8=16
# 2X9=18
# -----------
# 3X1=3
# 3X2=6
# 3X3=9
# 3X4=12
# 3X5=15
# 3X6=18
# 3X7=21
# 3X8=24
# 3X9=27
# -----------
# 4X1=4
# 4X2=8
# 4X3=12
# 4X4=16
# 4X5=20
# 4X6=24
# 4X7=28
# 4X8=32
# 4X9=36
# -----------
# 5X1=5
# 5X2=10
# 5X3=15
# 5X4=20
# 5X5=25
# 5X6=30
# 5X7=35
# 5X8=40
# 5X9=45
# -----------
# 6X1=6
# 6X2=12
# 6X3=18
# 6X4=24
# 6X5=30
# 6X6=36
# 6X7=42
# 6X8=48
# 6X9=54
# -----------
# 7X1=7
# 7X2=14
# 7X3=21
# 7X4=28
# 7X5=35
# 7X6=42
# 7X7=49
# 7X8=56
# 7X9=63
# -----------
# 8X1=8
# 8X2=16
# 8X3=24
# 8X4=32
# 8X5=40
# 8X6=48
# 8X7=56
# 8X8=64
# 8X9=72
# -----------
# 9X1=9
# 9X2=18
# 9X3=27
# 9X4=36
# 9X5=45
# 9X6=54
# 9X7=63
# 9X8=72
# 9X9=81

# %% [markdown]
# ## 제출 전 확인
#
# - ⭐ 기초는 **전부**, 위 난이도는 **도전**해보기 (다 못 풀어도 괜찮아요)
# - 각 문제의 **예상 출력과 결과가 같은지** 확인
# - **함수(`def`) 없이** 풀기 (오늘까지 배운 것만)
#
# 막히면 강의·실습을 다시 보거나, AI에게 **힌트만** 물어보세요(정답 통째로 X).
