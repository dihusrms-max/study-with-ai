# %% [markdown]
# # 실습 02-3 · 리스트와 튜플
#
# 강의(02-3)의 리스트·튜플 기본을 직접 풀어봅니다. (반복·조건은 아직 안 배웠으니 쓰지 않습니다.)
#
# 각 문제의 **빈칸을 채워** 실행하고, 예상 결과가 나오면 성공입니다. 막히면 아래 「정답 예시」를 참고하세요.

# %% [markdown]
# ## 문제 1
#
# 동물 리스트 `["사자","코끼리","펭귄","기린"]`에서 **두 번째**와 **마지막** 동물을 출력하세요.

# %%
# 여기에 작성하세요
# 힌트: 인덱스 0부터. 마지막은 [-1]

동물 = ["사자", "코끼리", "펭귄", "기린"]

print(동물[1])
print(동물[-1])
# Out:
# 코끼리
# 기린

# %%
# 정답 예시
동물 = ["사자", "코끼리", "펭귄", "기린"]
print("두 번째:", 동물[1])
print("마지막:", 동물[-1])
# 예상: 두 번째 코끼리 / 마지막 기린

# %% [markdown]
# ## 문제 2
#
# 수 리스트 `[10,20,30,40,50]`에서 **가운데 세 개**(20,30,40)를 슬라이싱으로 출력하세요.

# %%
# 여기에 작성하세요
# 힌트: [1:4]
nums = [10, 20, 30, 40, 50]
print(nums[1:4])
# Out:
# [20, 30, 40]

# %%
# 정답 예시
수 = [10, 20, 30, 40, 50]
print(수[1:4])
# 예상: [20, 30, 40]

# %% [markdown]
# ## 문제 3
#
# 가격 리스트 `[1200,3400,900]`에 **2500을 추가**하고, **개수·합계·평균**을 출력하세요.

# %%
# 여기에 작성하세요
# 힌트: append 후 len·sum

가격 = [1200, 3400, 900]
가격.append(2500)

# %%
개수 = len(가격)
합계 = sum(가격)
평균 = 합계 / 개수
print(f" 개수:{개수}\n 합계:{합계}\n 평균:{평균}")
# Out:
#  개수:4
#  합계:8000
#  평균:2000.0

# %%
# 정답 예시
가격 = [1200, 3400, 900]
가격.append(2500)
print("개수:", len(가격))
print("합계:", sum(가격))
print("평균:", sum(가격) / len(가격))
# 예상: 개수 4 / 합계 8000 / 평균 2000.0

# %% [markdown]
# ## 문제 4
#
# 점수 리스트 `[88,92,76,100,64]`의 **최고점·최저점**을 출력하세요.

# %%
# 여기에 작성하세요
# 힌트: max() / min()
점수 = [88, 92, 76, 100, 64]

print(max(점수))
print(min(점수))
# Out:
# 100
# 64

# %%
# 정답 예시
점수 = [88, 92, 76, 100, 64]
print("최고:", max(점수))
print("최저:", min(점수))
# 예상: 최고 100 / 최저 64

# %% [markdown]
# ## 문제 5
#
# 튜플 `(2026, 3, 15)`을 `연`,`월`,`일` 세 변수에 나눠 담아 `2026년 3월 15일`을 출력하세요.

# %%
# 여기에 작성하세요
# 힌트: 언패킹: 연, 월, 일 = 날짜
날짜 = (2026, 3, 15)
연, 월, 일 = 날짜
print(f"{연}년 {월}월 {일}일")
# 예상: 2026년 3월 15일
# Out:
# 2026년 3월 15일

# %%
날짜 = (2026, 3, 15)
리스트 = list(날짜)
연, 월, 일 = 리스트
print(f"{연} 년 {월} 월 {일}일")
# 예상: 2026년 3월 15일
# Out:
# 2026 년 3 월 15일

# %%
# 정답 예시
날짜 = (2026, 3, 15)
연, 월, 일 = 날짜
print(f"{연}년 {월}월 {일}일")
# 예상: 2026년 3월 15일

# %% [markdown]
# ## 정리
#
# 리스트로 여러 값을 담고 꺼내고 계산했습니다. 이 리스트를 **하나씩 돌며 거르는 건** 반복문(02-6)에서 배웁니다.
